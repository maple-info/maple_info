# %%
import nest_asyncio
import asyncio
import aiohttp
import json
from IPython.display import display, clear_output

# nest_asyncio를 적용하여 Jupyter Notebook에서도 asyncio.run을 사용 가능하게 설정
nest_asyncio.apply()

API_KEY = "test_c3a1c9dd9898748983795717d4054a73bb5713044ca4fec851806bea3c3a419aefe8d04e6d233bd35cf2fabdeb93fb0d"

async def fetch_data(api_url, params=None):
    headers = {
        "x-nxopen-api-key": API_KEY,
        "Content-Type": "application/json"
    }
    async with aiohttp.ClientSession() as session:
        async with session.get(api_url, headers=headers, params=params) as response:
            if response.status == 200:
                return await response.json()
            else:
                print(f"Error {response.status}: {response.reason} - Response: {await response.text()}")
                return None

async def get_ocid(character_name):
    base_url = "https://open.api.nexon.com/maplestory/v1/id"
    params = {"character_name": character_name}
    character_data = await fetch_data(base_url, params)
    if character_data and 'ocid' in character_data:
        return character_data['ocid']
    else:
        print(f"OCID를 찾을 수 없습니다. 캐릭터 이름: {character_name}")
        return None

async def main():
    character_name = "아델"
    base_url = "https://open.api.nexon.com/maplestory/v1/character"

    ocid = await get_ocid(character_name)
    if not ocid:
        return

    endpoints = {
        "item_equipment_info": "/item-equipment",
    }

    tasks = []
    for key, endpoint in endpoints.items():
        api_url = f"{base_url}{endpoint}"
        params = {"ocid": ocid}
        tasks.append(fetch_data(api_url, params))

    results = await asyncio.gather(*tasks)

    # JSON 파일로 저장
    with open(f"{character_name}_data.json", "w", encoding="utf-8") as json_file:
        json.dump(results, json_file, ensure_ascii=False, indent=4)

    # 결과 출력
    for (key, result) in zip(endpoints.keys(), results):
        clear_output(wait=True)
        print(f"\n{key} 응답 구조:")
        print(json.dumps(result, indent=4, ensure_ascii=False))
        await asyncio.sleep(3)

# Jupyter Notebook 환경에서 실행
await main()
# Out:
# item_equipment_info 응답 구조:
# {
#     "date": null,
#     "character_gender": "남",
#     "character_class": "아델",
#     "preset_no": 1,
#     "item_equipment": [
#         {
#             "item_equipment_part": "모자",
#             "item_equipment_slot": "모자",
#             "item_name": "에테르넬 나이트헬름",
#             "item_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEPCOOGB.png",
#             "item_description": null,
#             "item_shape_name": "에테르넬 나이트헬름",
#             "item_shape_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEPCOOGB.png",
#             "item_gender": null,
#             "item_total_option": {
#                 "str": "409",
#                 "dex": "303",
#                 "int": "140",
#                 "luk": "159",
#                 "max_hp": "255",
#                 "max_mp": "0",
#                 "attack_power": "225",
#                 "magic_power": "143",
#                 "armor": "2366",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "15",
#                 "all_stat": "6",
#                 "damage": "0",
#                 "equipment_level_decrease": 0,
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0"
#             },
#             "item_base_option": {
#                 "str": "80",
#                 "dex": "80",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "10",
#                 "magic_power": "0",
#                 "armor": "750",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "15",
#                 "all_stat": "0",
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0",
#                 "base_equipment_level": 250
#             },
#             "potential_option_grade": "레전드리",
#             "additional_potential_option_grade": "레전드리",
#             "potential_option_flag": "false",
#             "potential_option_1": "모든 스킬의 재사용 대기시간 : -2초(10초 이하는 10%감소, 5초 미만으로 감소 불가)",
#             "potential_option_2": "STR : +10%",
#             "potential_option_3": "모든 스킬의 재사용 대기시간 : -2초(10초 이하는 10%감소, 5초 미만으로 감소 불가)",
#             "additional_potential_option_flag": "false",
#             "additional_potential_option_1": "모든 스킬의 재사용 대기시간 : -1초(10초 이하는 5%감소, 5초 미만으로 감소 불가)",
#             "additional_potential_option_2": "STR : +7%",
#             "additional_potential_option_3": "올스탯 : +6%",
#             "equipment_level_increase": 0,
#             "item_exceptional_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "exceptional_upgrade": 0
#             },
#             "item_add_option": {
#                 "str": "135",
#                 "dex": "35",
#                 "int": "0",
#                 "luk": "28",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "damage": "0",
#                 "all_stat": "6",
#                 "equipment_level_decrease": 0
#             },
#             "growth_exp": 0,
#             "growth_level": 0,
#             "scroll_upgrade": "12",
#             "cuttable_count": "10",
#             "golden_hammer_flag": "적용",
#             "scroll_resilience_count": "0",
#             "scroll_upgradeable_count": "0",
#             "soul_name": null,
#             "soul_option": null,
#             "item_etc_option": {
#                 "str": "35",
#                 "dex": "29",
#                 "int": "21",
#                 "luk": "12",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "72",
#                 "magic_power": "0",
#                 "armor": "13",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "starforce": "23",
#             "starforce_scroll_flag": "미사용",
#             "item_starforce_option": {
#                 "str": "159",
#                 "dex": "159",
#                 "int": "119",
#                 "luk": "119",
#                 "max_hp": "255",
#                 "max_mp": "0",
#                 "attack_power": "143",
#                 "magic_power": "143",
#                 "armor": "1603",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "special_ring_level": 0,
#             "date_expire": null
#         },
#         {
#             "item_equipment_part": "얼굴장식",
#             "item_equipment_slot": "얼굴장식",
#             "item_name": "루즈 컨트롤 머신 마크",
#             "item_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEPDJBND.png",
#             "item_description": null,
#             "item_shape_name": "루즈 컨트롤 머신 마크",
#             "item_shape_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEPDJBND.png",
#             "item_gender": null,
#             "item_total_option": {
#                 "str": "290",
#                 "dex": "178",
#                 "int": "175",
#                 "luk": "151",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "157",
#                 "magic_power": "138",
#                 "armor": "668",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "0",
#                 "all_stat": "5",
#                 "damage": "0",
#                 "equipment_level_decrease": 0,
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0"
#             },
#             "item_base_option": {
#                 "str": "10",
#                 "dex": "10",
#                 "int": "10",
#                 "luk": "10",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "10",
#                 "magic_power": "10",
#                 "armor": "200",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "0",
#                 "all_stat": "0",
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0",
#                 "base_equipment_level": 160
#             },
#             "potential_option_grade": "레전드리",
#             "additional_potential_option_grade": "레전드리",
#             "potential_option_flag": "false",
#             "potential_option_1": "STR : +12%",
#             "potential_option_2": "STR : +12%",
#             "potential_option_3": "STR : +9%",
#             "additional_potential_option_flag": "false",
#             "additional_potential_option_1": "STR : +8%",
#             "additional_potential_option_2": "STR : +8%",
#             "additional_potential_option_3": "STR : +6%",
#             "equipment_level_increase": 0,
#             "item_exceptional_option": {
#                 "str": "15",
#                 "dex": "15",
#                 "int": "15",
#                 "luk": "15",
#                 "max_hp": "750",
#                 "max_mp": "750",
#                 "attack_power": "10",
#                 "magic_power": "10",
#                 "exceptional_upgrade": 1
#             },
#             "item_add_option": {
#                 "str": "113",
#                 "dex": "30",
#                 "int": "20",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "damage": "0",
#                 "all_stat": "5",
#                 "equipment_level_decrease": 0
#             },
#             "growth_exp": 0,
#             "growth_level": 0,
#             "scroll_upgrade": "6",
#             "cuttable_count": "5",
#             "golden_hammer_flag": "적용",
#             "scroll_resilience_count": "0",
#             "scroll_upgradeable_count": "0",
#             "soul_name": null,
#             "soul_option": null,
#             "item_etc_option": {
#                 "str": "36",
#                 "dex": "7",
#                 "int": "14",
#                 "luk": "10",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "36",
#                 "magic_power": "17",
#                 "armor": "10",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "starforce": "23",
#             "starforce_scroll_flag": "미사용",
#             "item_starforce_option": {
#                 "str": "131",
#                 "dex": "131",
#                 "int": "131",
#                 "luk": "131",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "111",
#                 "magic_power": "111",
#                 "armor": "458",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "special_ring_level": 0,
#             "date_expire": null
#         },
#         {
#             "item_equipment_part": "눈장식",
#             "item_equipment_slot": "눈장식",
#             "item_name": "마력이 깃든 안대",
#             "item_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEPAJFJJ.png",
#             "item_description": null,
#             "item_shape_name": "마력이 깃든 안대",
#             "item_shape_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEPAJFJJ.png",
#             "item_gender": null,
#             "item_total_option": {
#                 "str": "269",
#                 "dex": "178",
#                 "int": "177",
#                 "luk": "150",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "138",
#                 "magic_power": "126",
#                 "armor": "962",
#                 "speed": "10",
#                 "jump": "4",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "0",
#                 "all_stat": "7",
#                 "damage": "0",
#                 "equipment_level_decrease": 0,
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0"
#             },
#             "item_base_option": {
#                 "str": "15",
#                 "dex": "15",
#                 "int": "15",
#                 "luk": "15",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "3",
#                 "magic_power": "3",
#                 "armor": "300",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "0",
#                 "all_stat": "0",
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0",
#                 "base_equipment_level": 160
#             },
#             "potential_option_grade": "레전드리",
#             "additional_potential_option_grade": "레전드리",
#             "potential_option_flag": "false",
#             "potential_option_1": "STR : +12%",
#             "potential_option_2": "STR : +12%",
#             "potential_option_3": "STR : +12%",
#             "additional_potential_option_flag": "false",
#             "additional_potential_option_1": "STR : +8%",
#             "additional_potential_option_2": "올스탯 : +5%",
#             "additional_potential_option_3": "STR : +6%",
#             "equipment_level_increase": 0,
#             "item_exceptional_option": {
#                 "str": "15",
#                 "dex": "15",
#                 "int": "15",
#                 "luk": "15",
#                 "max_hp": "750",
#                 "max_mp": "750",
#                 "attack_power": "10",
#                 "magic_power": "10",
#                 "exceptional_upgrade": 1
#             },
#             "item_add_option": {
#                 "str": "99",
#                 "dex": "20",
#                 "int": "25",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "damage": "0",
#                 "all_stat": "7",
#                 "equipment_level_decrease": 0
#             },
#             "growth_exp": 0,
#             "growth_level": 0,
#             "scroll_upgrade": "4",
#             "cuttable_count": "5",
#             "golden_hammer_flag": "적용",
#             "scroll_resilience_count": "0",
#             "scroll_upgradeable_count": "0",
#             "soul_name": null,
#             "soul_option": null,
#             "item_etc_option": {
#                 "str": "24",
#                 "dex": "12",
#                 "int": "6",
#                 "luk": "4",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "24",
#                 "magic_power": "12",
#                 "armor": "7",
#                 "speed": "10",
#                 "jump": "4"
#             },
#             "starforce": "23",
#             "starforce_scroll_flag": "미사용",
#             "item_starforce_option": {
#                 "str": "131",
#                 "dex": "131",
#                 "int": "131",
#                 "luk": "131",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "111",
#                 "magic_power": "111",
#                 "armor": "655",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "special_ring_level": 0,
#             "date_expire": null
#         },
#         {
#             "item_equipment_part": "귀고리",
#             "item_equipment_slot": "귀고리",
#             "item_name": "커맨더 포스 이어링",
#             "item_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEPBJEPH.png",
#             "item_description": null,
#             "item_shape_name": "커맨더 포스 이어링",
#             "item_shape_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEPBJEPH.png",
#             "item_gender": null,
#             "item_total_option": {
#                 "str": "315",
#                 "dex": "194",
#                 "int": "200",
#                 "luk": "160",
#                 "max_hp": "570",
#                 "max_mp": "630",
#                 "attack_power": "174",
#                 "magic_power": "147",
#                 "armor": "350",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "0",
#                 "all_stat": "6",
#                 "damage": "0",
#                 "equipment_level_decrease": 0,
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0"
#             },
#             "item_base_option": {
#                 "str": "7",
#                 "dex": "7",
#                 "int": "7",
#                 "luk": "7",
#                 "max_hp": "500",
#                 "max_mp": "500",
#                 "attack_power": "5",
#                 "magic_power": "5",
#                 "armor": "100",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "0",
#                 "all_stat": "0",
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0",
#                 "base_equipment_level": 200
#             },
#             "potential_option_grade": "레전드리",
#             "additional_potential_option_grade": "레전드리",
#             "potential_option_flag": "false",
#             "potential_option_1": "STR : +12%",
#             "potential_option_2": "STR : +12%",
#             "potential_option_3": "STR : +12%",
#             "additional_potential_option_flag": "false",
#             "additional_potential_option_1": "STR : +8%",
#             "additional_potential_option_2": "올스탯 : +5%",
#             "additional_potential_option_3": "STR : +6%",
#             "equipment_level_increase": 0,
#             "item_exceptional_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "exceptional_upgrade": 0
#             },
#             "item_add_option": {
#                 "str": "121",
#                 "dex": "30",
#                 "int": "36",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "damage": "0",
#                 "all_stat": "6",
#                 "equipment_level_decrease": 0
#             },
#             "growth_exp": 0,
#             "growth_level": 0,
#             "scroll_upgrade": "7",
#             "cuttable_count": "4",
#             "golden_hammer_flag": "적용",
#             "scroll_resilience_count": "0",
#             "scroll_upgradeable_count": "0",
#             "soul_name": null,
#             "soul_option": null,
#             "item_etc_option": {
#                 "str": "42",
#                 "dex": "12",
#                 "int": "12",
#                 "luk": "8",
#                 "max_hp": "70",
#                 "max_mp": "130",
#                 "attack_power": "42",
#                 "magic_power": "15",
#                 "armor": "7",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "starforce": "23",
#             "starforce_scroll_flag": "미사용",
#             "item_starforce_option": {
#                 "str": "145",
#                 "dex": "145",
#                 "int": "145",
#                 "luk": "145",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "127",
#                 "magic_power": "127",
#                 "armor": "243",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "special_ring_level": 0,
#             "date_expire": null
#         },
#         {
#             "item_equipment_part": "상의",
#             "item_equipment_slot": "상의",
#             "item_name": "에테르넬 나이트아머",
#             "item_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEPGJDNC.png",
#             "item_description": null,
#             "item_shape_name": "에테르넬 나이트아머",
#             "item_shape_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEPGJDNC.png",
#             "item_gender": null,
#             "item_total_option": {
#                 "str": "406",
#                 "dex": "271",
#                 "int": "165",
#                 "luk": "138",
#                 "max_hp": "255",
#                 "max_mp": "0",
#                 "attack_power": "197",
#                 "magic_power": "143",
#                 "armor": "1062",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "5",
#                 "all_stat": "6",
#                 "damage": "0",
#                 "equipment_level_decrease": 0,
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0"
#             },
#             "item_base_option": {
#                 "str": "50",
#                 "dex": "50",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "6",
#                 "magic_power": "0",
#                 "armor": "325",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "5",
#                 "all_stat": "0",
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0",
#                 "base_equipment_level": 250
#             },
#             "potential_option_grade": "레전드리",
#             "additional_potential_option_grade": "레전드리",
#             "potential_option_flag": "false",
#             "potential_option_1": "STR : +13%",
#             "potential_option_2": "STR : +13%",
#             "potential_option_3": "STR : +13%",
#             "additional_potential_option_flag": "false",
#             "additional_potential_option_1": "STR : +9%",
#             "additional_potential_option_2": "STR : +7%",
#             "additional_potential_option_3": "올스탯 : +6%",
#             "equipment_level_increase": 0,
#             "item_exceptional_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "exceptional_upgrade": 0
#             },
#             "item_add_option": {
#                 "str": "149",
#                 "dex": "42",
#                 "int": "35",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "damage": "0",
#                 "all_stat": "6",
#                 "equipment_level_decrease": 0
#             },
#             "growth_exp": 0,
#             "growth_level": 0,
#             "scroll_upgrade": "8",
#             "cuttable_count": "9",
#             "golden_hammer_flag": "적용",
#             "scroll_resilience_count": "0",
#             "scroll_upgradeable_count": "0",
#             "soul_name": null,
#             "soul_option": null,
#             "item_etc_option": {
#                 "str": "48",
#                 "dex": "20",
#                 "int": "11",
#                 "luk": "19",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "48",
#                 "magic_power": "0",
#                 "armor": "15",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "starforce": "23",
#             "starforce_scroll_flag": "미사용",
#             "item_starforce_option": {
#                 "str": "159",
#                 "dex": "159",
#                 "int": "119",
#                 "luk": "119",
#                 "max_hp": "255",
#                 "max_mp": "0",
#                 "attack_power": "143",
#                 "magic_power": "143",
#                 "armor": "722",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "special_ring_level": 0,
#             "date_expire": null
#         },
#         {
#             "item_equipment_part": "하의",
#             "item_equipment_slot": "하의",
#             "item_name": "에테르넬 나이트팬츠",
#             "item_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEPEJFGE.png",
#             "item_description": null,
#             "item_shape_name": "에테르넬 나이트팬츠",
#             "item_shape_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEPEJFGE.png",
#             "item_gender": null,
#             "item_total_option": {
#                 "str": "406",
#                 "dex": "259",
#                 "int": "175",
#                 "luk": "132",
#                 "max_hp": "255",
#                 "max_mp": "0",
#                 "attack_power": "197",
#                 "magic_power": "143",
#                 "armor": "1045",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "5",
#                 "all_stat": "6",
#                 "damage": "0",
#                 "equipment_level_decrease": 0,
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0"
#             },
#             "item_base_option": {
#                 "str": "50",
#                 "dex": "50",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "6",
#                 "magic_power": "0",
#                 "armor": "325",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "5",
#                 "all_stat": "0",
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0",
#                 "base_equipment_level": 250
#             },
#             "potential_option_grade": "레전드리",
#             "additional_potential_option_grade": "레전드리",
#             "potential_option_flag": "false",
#             "potential_option_1": "STR : +13%",
#             "potential_option_2": "STR : +13%",
#             "potential_option_3": "STR : +13%",
#             "additional_potential_option_flag": "false",
#             "additional_potential_option_1": "STR : +9%",
#             "additional_potential_option_2": "올스탯 : +6%",
#             "additional_potential_option_3": "STR : +7%",
#             "equipment_level_increase": 0,
#             "item_exceptional_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "exceptional_upgrade": 0
#             },
#             "item_add_option": {
#                 "str": "149",
#                 "dex": "35",
#                 "int": "42",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "damage": "0",
#                 "all_stat": "6",
#                 "equipment_level_decrease": 0
#             },
#             "growth_exp": 0,
#             "growth_level": 0,
#             "scroll_upgrade": "8",
#             "cuttable_count": "10",
#             "golden_hammer_flag": "적용",
#             "scroll_resilience_count": "0",
#             "scroll_upgradeable_count": "0",
#             "soul_name": null,
#             "soul_option": null,
#             "item_etc_option": {
#                 "str": "48",
#                 "dex": "15",
#                 "int": "14",
#                 "luk": "13",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "48",
#                 "magic_power": "0",
#                 "armor": "9",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "starforce": "23",
#             "starforce_scroll_flag": "미사용",
#             "item_starforce_option": {
#                 "str": "159",
#                 "dex": "159",
#                 "int": "119",
#                 "luk": "119",
#                 "max_hp": "255",
#                 "max_mp": "0",
#                 "attack_power": "143",
#                 "magic_power": "143",
#                 "armor": "711",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "special_ring_level": 0,
#             "date_expire": null
#         },
#         {
#             "item_equipment_part": "신발",
#             "item_equipment_slot": "신발",
#             "item_name": "에테르넬 나이트슈즈",
#             "item_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEPFIBMI.png",
#             "item_description": null,
#             "item_shape_name": "에테르넬 나이트슈즈",
#             "item_shape_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEPFIBMI.png",
#             "item_gender": null,
#             "item_total_option": {
#                 "str": "394",
#                 "dex": "269",
#                 "int": "181",
#                 "luk": "131",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "180",
#                 "magic_power": "120",
#                 "armor": "995",
#                 "speed": "42",
#                 "jump": "49",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "0",
#                 "all_stat": "6",
#                 "damage": "0",
#                 "equipment_level_decrease": 0,
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0"
#             },
#             "item_base_option": {
#                 "str": "55",
#                 "dex": "55",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "12",
#                 "magic_power": "0",
#                 "armor": "325",
#                 "speed": "10",
#                 "jump": "7",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "0",
#                 "all_stat": "0",
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0",
#                 "base_equipment_level": 250
#             },
#             "potential_option_grade": "레전드리",
#             "additional_potential_option_grade": "레전드리",
#             "potential_option_flag": "false",
#             "potential_option_1": "STR : +13%",
#             "potential_option_2": "STR : +10%",
#             "potential_option_3": "STR : +13%",
#             "additional_potential_option_flag": "false",
#             "additional_potential_option_1": "STR : +9%",
#             "additional_potential_option_2": "STR : +7%",
#             "additional_potential_option_3": "올스탯 : +6%",
#             "equipment_level_increase": 0,
#             "item_exceptional_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "exceptional_upgrade": 0
#             },
#             "item_add_option": {
#                 "str": "156",
#                 "dex": "42",
#                 "int": "42",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "damage": "0",
#                 "all_stat": "6",
#                 "equipment_level_decrease": 0
#             },
#             "growth_exp": 0,
#             "growth_level": 0,
#             "scroll_upgrade": "8",
#             "cuttable_count": "10",
#             "golden_hammer_flag": "적용",
#             "scroll_resilience_count": "0",
#             "scroll_upgradeable_count": "0",
#             "soul_name": null,
#             "soul_option": null,
#             "item_etc_option": {
#                 "str": "24",
#                 "dex": "13",
#                 "int": "20",
#                 "luk": "12",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "48",
#                 "magic_power": "0",
#                 "armor": "9",
#                 "speed": "14",
#                 "jump": "24"
#             },
#             "starforce": "22",
#             "starforce_scroll_flag": "미사용",
#             "item_starforce_option": {
#                 "str": "159",
#                 "dex": "159",
#                 "int": "119",
#                 "luk": "119",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "120",
#                 "magic_power": "120",
#                 "armor": "661",
#                 "speed": "18",
#                 "jump": "18"
#             },
#             "special_ring_level": 0,
#             "date_expire": null
#         },
#         {
#             "item_equipment_part": "장갑",
#             "item_equipment_slot": "장갑",
#             "item_name": "에테르넬 나이트글러브",
#             "item_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEPKJAIB.png",
#             "item_description": null,
#             "item_shape_name": "에테르넬 나이트글러브",
#             "item_shape_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEPKJAIB.png",
#             "item_gender": null,
#             "item_total_option": {
#                 "str": "378",
#                 "dex": "258",
#                 "int": "173",
#                 "luk": "139",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "187",
#                 "magic_power": "120",
#                 "armor": "992",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "0",
#                 "all_stat": "6",
#                 "damage": "0",
#                 "equipment_level_decrease": 0,
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0"
#             },
#             "item_base_option": {
#                 "str": "55",
#                 "dex": "55",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "12",
#                 "magic_power": "0",
#                 "armor": "325",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "0",
#                 "all_stat": "0",
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0",
#                 "base_equipment_level": 250
#             },
#             "potential_option_grade": "레전드리",
#             "additional_potential_option_grade": "레전드리",
#             "potential_option_flag": "false",
#             "potential_option_1": "크리티컬 데미지 : +8%",
#             "potential_option_2": "크리티컬 데미지 : +8%",
#             "potential_option_3": "STR : +10%",
#             "additional_potential_option_flag": "false",
#             "additional_potential_option_1": "크리티컬 데미지 : +3%",
#             "additional_potential_option_2": "올스탯 : +6%",
#             "additional_potential_option_3": "STR : +7%",
#             "equipment_level_increase": 0,
#             "item_exceptional_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "exceptional_upgrade": 0
#             },
#             "item_add_option": {
#                 "str": "154",
#                 "dex": "35",
#                 "int": "35",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "damage": "0",
#                 "all_stat": "6",
#                 "equipment_level_decrease": 0
#             },
#             "growth_exp": 0,
#             "growth_level": 0,
#             "scroll_upgrade": "8",
#             "cuttable_count": "10",
#             "golden_hammer_flag": "적용",
#             "scroll_resilience_count": "0",
#             "scroll_upgradeable_count": "0",
#             "soul_name": null,
#             "soul_option": null,
#             "item_etc_option": {
#                 "str": "10",
#                 "dex": "9",
#                 "int": "19",
#                 "luk": "20",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "48",
#                 "magic_power": "0",
#                 "armor": "8",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "starforce": "22",
#             "starforce_scroll_flag": "미사용",
#             "item_starforce_option": {
#                 "str": "159",
#                 "dex": "159",
#                 "int": "119",
#                 "luk": "119",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "127",
#                 "magic_power": "120",
#                 "armor": "659",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "special_ring_level": 0,
#             "date_expire": null
#         },
#         {
#             "item_equipment_part": "망토",
#             "item_equipment_slot": "망토",
#             "item_name": "에테르넬 나이트케이프",
#             "item_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEOCIDNC.png",
#             "item_description": null,
#             "item_shape_name": "에테르넬 나이트케이프",
#             "item_shape_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEOCIDNC.png",
#             "item_gender": null,
#             "item_total_option": {
#                 "str": "377",
#                 "dex": "223",
#                 "int": "221",
#                 "luk": "235",
#                 "max_hp": "255",
#                 "max_mp": "0",
#                 "attack_power": "177",
#                 "magic_power": "144",
#                 "armor": "1823",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "0",
#                 "all_stat": "5",
#                 "damage": "0",
#                 "equipment_level_decrease": 0,
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0"
#             },
#             "item_base_option": {
#                 "str": "50",
#                 "dex": "50",
#                 "int": "50",
#                 "luk": "50",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "9",
#                 "magic_power": "9",
#                 "armor": "600",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "0",
#                 "all_stat": "0",
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0",
#                 "base_equipment_level": 250
#             },
#             "potential_option_grade": "레전드리",
#             "additional_potential_option_grade": "레전드리",
#             "potential_option_flag": "false",
#             "potential_option_1": "STR : +13%",
#             "potential_option_2": "STR : +10%",
#             "potential_option_3": "STR : +13%",
#             "additional_potential_option_flag": "false",
#             "additional_potential_option_1": "올스탯 : +7%",
#             "additional_potential_option_2": "올스탯 : +6%",
#             "additional_potential_option_3": "올스탯 : +6%",
#             "equipment_level_increase": 0,
#             "item_exceptional_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "exceptional_upgrade": 0
#             },
#             "item_add_option": {
#                 "str": "144",
#                 "dex": "0",
#                 "int": "42",
#                 "luk": "42",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "damage": "0",
#                 "all_stat": "5",
#                 "equipment_level_decrease": 0
#             },
#             "growth_exp": 0,
#             "growth_level": 0,
#             "scroll_upgrade": "8",
#             "cuttable_count": "10",
#             "golden_hammer_flag": "적용",
#             "scroll_resilience_count": "0",
#             "scroll_upgradeable_count": "0",
#             "soul_name": null,
#             "soul_option": null,
#             "item_etc_option": {
#                 "str": "24",
#                 "dex": "14",
#                 "int": "10",
#                 "luk": "24",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "48",
#                 "magic_power": "15",
#                 "armor": "18",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "starforce": "22",
#             "starforce_scroll_flag": "미사용",
#             "item_starforce_option": {
#                 "str": "159",
#                 "dex": "159",
#                 "int": "119",
#                 "luk": "119",
#                 "max_hp": "255",
#                 "max_mp": "0",
#                 "attack_power": "120",
#                 "magic_power": "120",
#                 "armor": "1205",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "special_ring_level": 0,
#             "date_expire": null
#         },
#         {
#             "item_equipment_part": "브레이슬릿",
#             "item_equipment_slot": "보조무기",
#             "item_name": "노블 브레이슬릿",
#             "item_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEMHPHOC.png",
#             "item_description": null,
#             "item_shape_name": "노블 브레이슬릿",
#             "item_shape_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEMHPHOC.png",
#             "item_gender": null,
#             "item_total_option": {
#                 "str": "10",
#                 "dex": "10",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "3",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "0",
#                 "all_stat": "0",
#                 "damage": "0",
#                 "equipment_level_decrease": 0,
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0"
#             },
#             "item_base_option": {
#                 "str": "10",
#                 "dex": "10",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "3",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "0",
#                 "all_stat": "0",
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0",
#                 "base_equipment_level": 100
#             },
#             "potential_option_grade": "레전드리",
#             "additional_potential_option_grade": "레전드리",
#             "potential_option_flag": "false",
#             "potential_option_1": "보스 몬스터 공격 시 데미지 : +40%",
#             "potential_option_2": "보스 몬스터 공격 시 데미지 : +30%",
#             "potential_option_3": "공격력 : +12%",
#             "additional_potential_option_flag": "false",
#             "additional_potential_option_1": "공격력 : +12%",
#             "additional_potential_option_2": "공격력 : +9%",
#             "additional_potential_option_3": "공격력 : +12%",
#             "equipment_level_increase": 0,
#             "item_exceptional_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "exceptional_upgrade": 0
#             },
#             "item_add_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "damage": "0",
#                 "all_stat": "0",
#                 "equipment_level_decrease": 0
#             },
#             "growth_exp": 0,
#             "growth_level": 0,
#             "scroll_upgrade": "0",
#             "cuttable_count": "255",
#             "golden_hammer_flag": "미적용",
#             "scroll_resilience_count": "0",
#             "scroll_upgradeable_count": "0",
#             "soul_name": null,
#             "soul_option": null,
#             "item_etc_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "starforce": "0",
#             "starforce_scroll_flag": "미사용",
#             "item_starforce_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "special_ring_level": 0,
#             "date_expire": null
#         },
#         {
#             "item_equipment_part": "튜너",
#             "item_equipment_slot": "무기",
#             "item_name": "제네시스 튜너",
#             "item_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KENDIHMD.png",
#             "item_description": null,
#             "item_shape_name": "제네시스 튜너",
#             "item_shape_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KENDIHMD.png",
#             "item_gender": null,
#             "item_total_option": {
#                 "str": "371",
#                 "dex": "295",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "255",
#                 "max_mp": "255",
#                 "attack_power": "875",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "40",
#                 "ignore_monster_armor": "20",
#                 "all_stat": "0",
#                 "damage": "5",
#                 "equipment_level_decrease": 0,
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0"
#             },
#             "item_base_option": {
#                 "str": "150",
#                 "dex": "150",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "340",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "30",
#                 "ignore_monster_armor": "20",
#                 "all_stat": "0",
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0",
#                 "base_equipment_level": 200
#             },
#             "potential_option_grade": "레전드리",
#             "additional_potential_option_grade": "레전드리",
#             "potential_option_flag": "false",
#             "potential_option_1": "보스 몬스터 공격 시 데미지 : +40%",
#             "potential_option_2": "보스 몬스터 공격 시 데미지 : +40%",
#             "potential_option_3": "보스 몬스터 공격 시 데미지 : +30%",
#             "additional_potential_option_flag": "false",
#             "additional_potential_option_1": "공격력 : +12%",
#             "additional_potential_option_2": "공격력 : +9%",
#             "additional_potential_option_3": "공격력 : +9%",
#             "equipment_level_increase": 0,
#             "item_exceptional_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "exceptional_upgrade": 0
#             },
#             "item_add_option": {
#                 "str": "44",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "210",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "10",
#                 "damage": "5",
#                 "all_stat": "0",
#                 "equipment_level_decrease": 0
#             },
#             "growth_exp": 0,
# ...
#             "additional_potential_option_1": null,
#             "additional_potential_option_2": null,
#             "additional_potential_option_3": null,
#             "equipment_level_increase": 0,
#             "item_exceptional_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "exceptional_upgrade": 0
#             },
#             "item_add_option": {
#                 "str": "109",
#                 "dex": "0",
#                 "int": "25",
#                 "luk": "30",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "damage": "0",
#                 "all_stat": "7",
#                 "equipment_level_decrease": 0
#             },
#             "growth_exp": 0,
#             "growth_level": 0,
#             "scroll_upgrade": "0",
#             "cuttable_count": "255",
#             "golden_hammer_flag": "미적용",
#             "scroll_resilience_count": "0",
#             "scroll_upgradeable_count": "0",
#             "soul_name": null,
#             "soul_option": null,
#             "item_etc_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "starforce": "0",
#             "starforce_scroll_flag": "미사용",
#             "item_starforce_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "special_ring_level": 0,
#             "date_expire": null
#         },
#         {
#             "item_equipment_part": "기계 심장",
#             "item_equipment_slot": "기계 심장",
#             "item_name": "컴플리트 언더컨트롤",
#             "item_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEJFJHHE.png",
#             "item_description": null,
#             "item_shape_name": "컴플리트 언더컨트롤",
#             "item_shape_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEJFJHHE.png",
#             "item_gender": null,
#             "item_total_option": {
#                 "str": "200",
#                 "dex": "200",
#                 "int": "200",
#                 "luk": "200",
#                 "max_hp": "1250",
#                 "max_mp": "0",
#                 "attack_power": "231",
#                 "magic_power": "121",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "30",
#                 "all_stat": "0",
#                 "damage": "0",
#                 "equipment_level_decrease": 0,
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0"
#             },
#             "item_base_option": {
#                 "str": "25",
#                 "dex": "25",
#                 "int": "25",
#                 "luk": "25",
#                 "max_hp": "1250",
#                 "max_mp": "0",
#                 "attack_power": "15",
#                 "magic_power": "15",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "30",
#                 "all_stat": "0",
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0",
#                 "base_equipment_level": 200
#             },
#             "potential_option_grade": "레전드리",
#             "additional_potential_option_grade": "레전드리",
#             "potential_option_flag": "false",
#             "potential_option_1": "STR : +12%",
#             "potential_option_2": "STR : +12%",
#             "potential_option_3": "STR : +9%",
#             "additional_potential_option_flag": "false",
#             "additional_potential_option_1": "캐릭터 기준 9레벨 당 STR : +2",
#             "additional_potential_option_2": "STR : +6%",
#             "additional_potential_option_3": "STR : +6%",
#             "equipment_level_increase": 0,
#             "item_exceptional_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "exceptional_upgrade": 0
#             },
#             "item_add_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "damage": "0",
#                 "all_stat": "0",
#                 "equipment_level_decrease": 0
#             },
#             "growth_exp": 0,
#             "growth_level": 0,
#             "scroll_upgrade": "10",
#             "cuttable_count": "255",
#             "golden_hammer_flag": "적용",
#             "scroll_resilience_count": "0",
#             "scroll_upgradeable_count": "0",
#             "soul_name": null,
#             "soul_option": null,
#             "item_etc_option": {
#                 "str": "30",
#                 "dex": "30",
#                 "int": "30",
#                 "luk": "30",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "110",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "starforce": "22",
#             "starforce_scroll_flag": "미사용",
#             "item_starforce_option": {
#                 "str": "145",
#                 "dex": "145",
#                 "int": "145",
#                 "luk": "145",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "106",
#                 "magic_power": "106",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "special_ring_level": 0,
#             "date_expire": null
#         },
#         {
#             "item_equipment_part": "뱃지",
#             "item_equipment_slot": "뱃지",
#             "item_name": "창세의 뱃지",
#             "item_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEOKJFGE.png",
#             "item_description": null,
#             "item_shape_name": "창세의 뱃지",
#             "item_shape_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEOKJFGE.png",
#             "item_gender": null,
#             "item_total_option": {
#                 "str": "15",
#                 "dex": "15",
#                 "int": "15",
#                 "luk": "15",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "10",
#                 "magic_power": "10",
#                 "armor": "0",
#                 "speed": "10",
#                 "jump": "10",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "0",
#                 "all_stat": "0",
#                 "damage": "0",
#                 "equipment_level_decrease": 0,
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0"
#             },
#             "item_base_option": {
#                 "str": "15",
#                 "dex": "15",
#                 "int": "15",
#                 "luk": "15",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "10",
#                 "magic_power": "10",
#                 "armor": "0",
#                 "speed": "10",
#                 "jump": "10",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "0",
#                 "all_stat": "0",
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0",
#                 "base_equipment_level": 200
#             },
#             "potential_option_grade": null,
#             "additional_potential_option_grade": null,
#             "potential_option_flag": "false",
#             "potential_option_1": null,
#             "potential_option_2": null,
#             "potential_option_3": null,
#             "additional_potential_option_flag": "false",
#             "additional_potential_option_1": null,
#             "additional_potential_option_2": null,
#             "additional_potential_option_3": null,
#             "equipment_level_increase": 0,
#             "item_exceptional_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "exceptional_upgrade": 0
#             },
#             "item_add_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "damage": "0",
#                 "all_stat": "0",
#                 "equipment_level_decrease": 0
#             },
#             "growth_exp": 0,
#             "growth_level": 0,
#             "scroll_upgrade": "0",
#             "cuttable_count": "255",
#             "golden_hammer_flag": "미적용",
#             "scroll_resilience_count": "0",
#             "scroll_upgradeable_count": "0",
#             "soul_name": null,
#             "soul_option": null,
#             "item_etc_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "starforce": "0",
#             "starforce_scroll_flag": "미사용",
#             "item_starforce_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "special_ring_level": 0,
#             "date_expire": null
#         },
#         {
#             "item_equipment_part": "엠블렘",
#             "item_equipment_slot": "엠블렘",
#             "item_name": "미트라의 분노 : 전사",
#             "item_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEOLLCLE.png",
#             "item_description": null,
#             "item_shape_name": "미트라의 분노 : 전사",
#             "item_shape_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KEOLLCLE.png",
#             "item_gender": null,
#             "item_total_option": {
#                 "str": "40",
#                 "dex": "40",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "700",
#                 "max_mp": "0",
#                 "attack_power": "5",
#                 "magic_power": "5",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "0",
#                 "all_stat": "0",
#                 "damage": "0",
#                 "equipment_level_decrease": 0,
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0"
#             },
#             "item_base_option": {
#                 "str": "40",
#                 "dex": "40",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "700",
#                 "max_mp": "0",
#                 "attack_power": "5",
#                 "magic_power": "5",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "ignore_monster_armor": "0",
#                 "all_stat": "0",
#                 "max_hp_rate": "0",
#                 "max_mp_rate": "0",
#                 "base_equipment_level": 200
#             },
#             "potential_option_grade": "레전드리",
#             "additional_potential_option_grade": "레전드리",
#             "potential_option_flag": "false",
#             "potential_option_1": "공격력 : +12%",
#             "potential_option_2": "공격력 : +12%",
#             "potential_option_3": "공격력 : +12%",
#             "additional_potential_option_flag": "false",
#             "additional_potential_option_1": "공격력 : +12%",
#             "additional_potential_option_2": "공격력 : +9%",
#             "additional_potential_option_3": "공격력 : +9%",
#             "equipment_level_increase": 0,
#             "item_exceptional_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "exceptional_upgrade": 0
#             },
#             "item_add_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0",
#                 "boss_damage": "0",
#                 "damage": "0",
#                 "all_stat": "0",
#                 "equipment_level_decrease": 0
#             },
#             "growth_exp": 0,
#             "growth_level": 0,
#             "scroll_upgrade": "0",
#             "cuttable_count": "255",
#             "golden_hammer_flag": "미적용",
#             "scroll_resilience_count": "0",
#             "scroll_upgradeable_count": "0",
#             "soul_name": null,
#             "soul_option": null,
#             "item_etc_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "starforce": "0",
#             "starforce_scroll_flag": "미사용",
#             "item_starforce_option": {
#                 "str": "0",
#                 "dex": "0",
#                 "int": "0",
#                 "luk": "0",
#                 "max_hp": "0",
#                 "max_mp": "0",
#                 "attack_power": "0",
#                 "magic_power": "0",
#                 "armor": "0",
#                 "speed": "0",
#                 "jump": "0"
#             },
#             "special_ring_level": 0,
#             "date_expire": null
#         }
#     ],
#     "title": {
#         "title_name": "영웅",
#         "title_icon": "https://open.api.nexon.com/static/maplestory/ItemIcon/KGICLAIF.png",
#         "title_description": "This Story is Not Over.\n\n보스 몬스터 공격 시 데미지 +30%\n방어율 무시+30%\n공격력/마력+30\n옵션 적용 기간: 30일\n\n클릭으로 ON/OFF시킬 수 있다.",
#         "date_expire": null,
#         "date_option_expire": "2024-10-19T23:38+09:00"
#     },
#     "dragon_equipment": [],
#     "mechanic_equipment": []
# }

# %%
async def main():
    character_name = "무당햄스터"
    base_url = "https://open.api.nexon.com/maplestory/v1/character"

    ocid = await get_ocid(character_name)
    if not ocid:
        return

    endpoints = {
        "link_skill_info": "/link-skill",
        "hyper_stat_info": "/hyper-stat",
        "symbol_equipment_info": "/symbol-equipment",
        "hexamatrix_stat_info": "/hexamatrix-stat",
    }

    tasks = []
    for key, endpoint in endpoints.items():
        api_url = f"{base_url}{endpoint}"
        params = {"ocid": ocid}
        tasks.append(fetch_data(api_url, params))

    results = await asyncio.gather(*tasks)

    # JSON 파일로 저장
    with open(f"{character_name}_data_2.json", "w", encoding="utf-8") as json_file:
        json.dump(results, json_file, ensure_ascii=False, indent=4)

    # 결과 출력
    for (key, result) in zip(endpoints.keys(), results):
        clear_output(wait=True)
        print(f"\n{key} 응답 구조:")
        print(json.dumps(result, indent=4, ensure_ascii=False))
        await asyncio.sleep(3)

# Jupyter Notebook 환경에서 실행
await main()
# Out:
# hexamatrix_stat_info 응답 구조:
# {
#     "date": null,
#     "character_class": "일리움",
#     "character_hexa_stat_core": [
#         {
#             "slot_id": "0",
#             "main_stat_name": "주력 스탯 증가",
#             "sub_stat_name_1": "마력 증가",
#             "sub_stat_name_2": "보스 데미지 증가",
#             "main_stat_level": 3,
#             "sub_stat_level_1": 6,
#             "sub_stat_level_2": 0,
#             "stat_grade": 9
#         }
#     ],
#     "character_hexa_stat_core_2": [],
#     "preset_hexa_stat_core": [
#         {
#             "slot_id": "0",
#             "main_stat_name": "주력 스탯 증가",
#             "sub_stat_name_1": "마력 증가",
#             "sub_stat_name_2": "보스 데미지 증가",
#             "main_stat_level": 3,
#             "sub_stat_level_1": 6,
#             "sub_stat_level_2": 0,
#             "stat_grade": 9
#         },
#         {
#             "slot_id": "1",
#             "main_stat_name": null,
#             "sub_stat_name_1": null,
#             "sub_stat_name_2": null,
#             "main_stat_level": 0,
#             "sub_stat_level_1": 0,
#             "sub_stat_level_2": 0,
#             "stat_grade": 0
#         }
#     ],
#     "preset_hexa_stat_core_2": []
# }
